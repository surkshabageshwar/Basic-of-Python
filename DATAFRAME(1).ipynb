# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir("C:\\Users\\Abhi's PC\\Downloads\\download")

# %%
os.getcwd()
# Out:
# "C:\\Users\\Abhi's PC\\Downloads\\download"

# %%
data=pd.read_csv('tips.csv')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
len(data)
# Out:
# 244

# %%
len(data.columns)
# Out:
# 7

# %%
list(data.columns)
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.columns=['totalbill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
data
# Out:
#      totalbill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 1        10.34  1.66    Male     No   Sun  Dinner     3
# 2        21.01  3.50    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# 5        25.29  4.71    Male     No   Sun  Dinner     4
# 6         8.77  2.00    Male     No   Sun  Dinner     2
# 7        26.88  3.12    Male     No   Sun  Dinner     4
# 8        15.04  1.96    Male     No   Sun  Dinner     2
# 9        14.78  3.23    Male     No   Sun  Dinner     2
# 10       10.27  1.71    Male     No   Sun  Dinner     2
# 11       35.26  5.00  Female     No   Sun  Dinner     4
# 12       15.42  1.57    Male     No   Sun  Dinner     2
# 13       18.43  3.00    Male     No   Sun  Dinner     4
# 14       14.83  3.02  Female     No   Sun  Dinner     2
# 15       21.58  3.92    Male     No   Sun  Dinner     2
# ...

# %%
data=data.rename(columns={"totalbill":'total_bill'})

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data['mycal']=data.total_bill*data.tip

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size     mycal
# 0         16.99  1.01  Female     No   Sun  Dinner     2   17.1599
# 1         10.34  1.66    Male     No   Sun  Dinner     3   17.1644
# 2         21.01  3.50    Male     No   Sun  Dinner     3   73.5350
# 3         23.68  3.31    Male     No   Sun  Dinner     2   78.3808
# 4         24.59  3.61  Female     No   Sun  Dinner     4   88.7699
# 5         25.29  4.71    Male     No   Sun  Dinner     4  119.1159
# 6          8.77  2.00    Male     No   Sun  Dinner     2   17.5400
# 7         26.88  3.12    Male     No   Sun  Dinner     4   83.8656
# 8         15.04  1.96    Male     No   Sun  Dinner     2   29.4784
# 9         14.78  3.23    Male     No   Sun  Dinner     2   47.7394
# 10        10.27  1.71    Male     No   Sun  Dinner     2   17.5617
# 11        35.26  5.00  Female     No   Sun  Dinner     4  176.3000
# 12        15.42  1.57    Male     No   Sun  Dinner     2   24.2094
# ...

# %%
data=data.drop('mycal',1)

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data[['total_bill', 'tip', 'sex', 'smoker', 'day']].head()
# Out:
#    total_bill   tip     sex smoker  day
# 0       16.99  1.01  Female     No  Sun
# 1       10.34  1.66    Male     No  Sun
# 2       21.01  3.50    Male     No  Sun
# 3       23.68  3.31    Male     No  Sun
# 4       24.59  3.61  Female     No  Sun

# %%
data[data.smoker.isna()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
data[data.smoker.notna()]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data[(data['time']=='Dinner')&(data['size']>3)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 13        18.43  3.00    Male     No  Sun  Dinner     4
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# 25        17.81  2.34    Male     No  Sat  Dinner     4
# 31        18.35  2.50    Male     No  Sat  Dinner     4
# 33        20.69  2.45  Female     No  Sat  Dinner     4
# 44        30.40  5.60    Male     No  Sun  Dinner     4
# 47        32.40  6.00    Male     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 54        25.56  4.34    Male     No  Sun  Dinner     4
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 59        48.27  6.73    Male     No  Sat  Dinner     4
# 63        18.29  3.76    Male    Yes  Sat  Dinner     4
# ...

# %%
data[(data['time']=='Lunch')|(data['size']>4)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 84        15.98  2.03    Male     No  Thur   Lunch     2
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 87        18.28  4.00    Male     No  Thur   Lunch     2
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 89        21.16  3.00    Male     No  Thur   Lunch     2
# 117       10.65  1.50  Female     No  Thur   Lunch     2
# 118       12.43  1.80  Female     No  Thur   Lunch     2
# ...

# %%
data.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %%
data.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %%
data.groupby('size').agg({'tip':np.mean})
# Out:
#            tip
# size
# 1     1.437500
# 2     2.582308
# 3     3.393158
# 4     4.135405
# 5     4.028000
# 6     5.225000

# %%
data.groupby('size').agg({'tip':[np.mean,np.sum]})
# Out:
#            tip
#           mean     sum
# size
# 1     1.437500    5.75
# 2     2.582308  402.84
# 3     3.393158  128.94
# 4     4.135405  153.01
# 5     4.028000   20.14
# 6     5.225000   20.90

# %%
sns.lmplot(data=data,x='total_bill',y='tip',fit_reg=False,hue='smoker')
