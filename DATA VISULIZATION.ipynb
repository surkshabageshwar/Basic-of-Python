# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
year=[2011,2012,2013,2014]
sale=[1235,4328,8767,5679]
profit=[126,321,346,643]

# %%
plt.scatter(year,sale)

# %%
os.chdir("C:\\Users\\Abhi's PC\\Desktop\\New folder\\a my csv or excel file")

# %%
os.getcwd()
# Out:
# "C:\\Users\\Abhi's PC\\Desktop\\New folder\\a my csv or excel file"

# %%
file=pd.read_excel('Sample - Superstore.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
file
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 5          6  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 6          7  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 7          8  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 8          9  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 9         10  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 10        11  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 11        12  CA-2015-115812 2015-06-09 2015-06-14  Standard Class
# 12        13  CA-2018-114412 2018-04-15 2018-04-20  Standard Class
# ...

# %%
len(file)
# Out:
# 9994

# %%
file.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
file['Quantity'].plot.hist()

# %%
sns.distplot(file['Quantity'])
# Out:
# D:\an\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(file['Quantity'],kde=False)

# %%
sns.lmplot(data=file,x='Sales',y='Profit',fit_reg=False,hue='Segment')

# %%
sns.regplot(data=file,x='Sales',y='Quantity',hue='Segment')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-23ec115574ee> in <module>
# ----> 1 sns.regplot(data=file,x='Sales',y='Quantity',hue='Segment')
#
# TypeError: regplot() got an unexpected keyword argument 'hue'

# %%
sns.jointplot(data=file,x='Sales',y='Profit')

# %%
sns.countplot(data=file,x='Category')

# %%
sns.barplot(data=file,y='Sales',x='Category')

# %%
sns.stripplot(data=file,y='Sales',x='Segment')

# %%
file_pp=pd.read_excel('pairplot.xls')

# %%
file_pp
# Out:
#           Sales  Quantity  Discount     Profit
# 0      261.9600         2      0.00    41.9136
# 1      731.9400         3      0.00   219.5820
# 2       14.6200         2      0.00     6.8714
# 3      957.5775         5      0.45  -383.0310
# 4       22.3680         2      0.20     2.5164
# 5       48.8600         7      0.00    14.1694
# 6        7.2800         4      0.00     1.9656
# 7      907.1520         6      0.20    90.7152
# 8       18.5040         3      0.20     5.7825
# 9      114.9000         5      0.00    34.4700
# 10    1706.1840         9      0.20    85.3092
# 11     911.4240         4      0.20    68.3568
# 12      15.5520         3      0.20     5.4432
# 13     407.9760         3      0.20   132.5922
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 16     665.8800         6      0.00    13.3176
# 17      55.5000         2      0.00     9.9900
# 18       8.5600         2      0.00     2.4824
# ...

# %%
len(file_pp)
# Out:
# 9994

# %%
file_pp.columns
# Out:
# Index(['Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
sns.pairplot(file_pp)

# %%
sns.heatmap(file_pp.corr(),annot=True)

# %%
file_ts=pd.read_csv('airline_passengers.csv')

# %%
file_ts
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                      112
# 1    1949-02                      118
# 2    1949-03                      132
# 3    1949-04                      129
# 4    1949-05                      121
# 5    1949-06                      135
# 6    1949-07                      148
# 7    1949-08                      148
# 8    1949-09                      136
# 9    1949-10                      119
# 10   1949-11                      104
# 11   1949-12                      118
# 12   1950-01                      115
# 13   1950-02                      126
# 14   1950-03                      141
# 15   1950-04                      135
# 16   1950-05                      125
# 17   1950-06                      149
# 18   1950-07                      170
# 19   1950-08                      170
# 20   1950-09                      158
# 21   1950-10                      133
# 22   1950-11                      114
# 23   1950-12                      140
# ...

# %%
file_ts.plot()

# %%
file_ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
# Month                      144 non-null object
# Thousands of Passengers    144 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
file_ts['Month']=pd.to_datetime(file_ts['Month'])

# %%
file_ts=file_ts.set_index('Month')

# %%
file_ts
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# 1949-06-01                      135
# 1949-07-01                      148
# 1949-08-01                      148
# 1949-09-01                      136
# 1949-10-01                      119
# 1949-11-01                      104
# 1949-12-01                      118
# 1950-01-01                      115
# 1950-02-01                      126
# 1950-03-01                      141
# 1950-04-01                      135
# 1950-05-01                      125
# 1950-06-01                      149
# 1950-07-01                      170
# 1950-08-01                      170
# 1950-09-01                      158
# 1950-10-01                      133
# 1950-11-01                      114
# 1950-12-01                      140
# 1951-01-01                      145
# ...

# %%
file_ts.plot()

# %%
file_ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
# Thousands of Passengers    144 non-null int64
# dtypes: int64(1)
# memory usage: 2.2 KB
