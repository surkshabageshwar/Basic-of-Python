# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir("C:\\Users\\Abhi's PC\\Downloads\\download")

# %%
os.getcwd()
# Out:
# "C:\\Users\\Abhi's PC\\Downloads\\download"

# %%
data=pd.read_excel('Employee_Data.xls')

# %%
data
# Out:
#     Employee Id First Name   Last Name           Department   Age  Experience  \
# 0             1        Joy        Bass  Sales and Marketing  28.0         3.0
# 1             2     Sheila       Garza  Sales and Marketing  22.0         1.0
# 2             3       John      Bryant   Customer Relations  22.0         1.0
# 3             4  Christian      Farley   Customer Relations  22.0         1.0
# 4             5   Colorado       Bowen           Accounting  27.0         0.0
# 5             6     Elijah    Matthews           Accounting  26.0         5.0
# 6             7         Bo      Mcleod   Customer Relations  24.0         6.0
# 7             8       Zena    Melendez   Customer Relations  29.0         2.0
# 8             9     Tucker     Michael  Sales and Marketing  29.0         5.0
# 9            10      Lucas        Rowe   Customer Relations  30.0         6.0
# 10           11    Mallory      Walker           Accounting  26.0         5.0
# ...

# %%
len(data)
# Out:
# 100

# %%
len(data.columns)
# Out:
# 7

# %%
list(data.columns)
# Out:
# ['Employee Id',
#  'First Name',
#  'Last Name',
#  'Department',
#  'Age',
#  'Experience',
#  'Salary']

# %%
data.head()
# Out:
#    Employee Id First Name Last Name           Department   Age  Experience  \
# 0            1        Joy      Bass  Sales and Marketing  28.0         3.0
# 1            2     Sheila     Garza  Sales and Marketing  22.0         1.0
# 2            3       John    Bryant   Customer Relations  22.0         1.0
# 3            4  Christian    Farley   Customer Relations  22.0         1.0
# 4            5   Colorado     Bowen           Accounting  27.0         0.0
#
#    Salary
# 0   32889
# 1   15944
# 2   40343
# 3   19018
# 4   24795

# %%
data.describe()
# Out:
#        Employee Id        Age  Experience        Salary
# count   100.000000  82.000000   90.000000    100.000000
# mean     50.500000  37.975610   14.766667  65066.760000
# std      29.011492   9.515388    6.889252  26189.874212
# min       1.000000  22.000000    0.000000  11830.000000
# 25%      25.750000  27.250000    9.250000  48526.000000
# 50%      50.500000  42.000000   16.500000  73500.500000
# 75%      75.250000  45.750000   21.000000  86621.250000
# max     100.000000  50.000000   25.000000  98180.000000

# %%
data.isnull().sum()
# Out:
# Employee Id     0
# First Name      0
# Last Name       0
# Department     19
# Age            18
# Experience     10
# Salary          0
# dtype: int64

# %%
sns.boxplot(data=data,y='Age')

# %%
sns.boxplot(data=data,y='Experience')

# %%
x=data.iloc[:,3:6].values

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, nan],
#        ['Customer Relations', 22.0, nan],
#        ['Accounting', 25.0, nan],
#        ['Accounting', 27.0, nan],
#        [nan, 25.0, nan],
#        [nan, 22.0, nan],
#        [nan, 22.0, nan],
#        [nan, 24.0, nan],
#        [nan, 27.0, nan],
#        [nan, 22.0, nan],
#        [nan, 33.0, 13.0],
#        [nan, 36.0, 7.0],
# ...

# %%
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values='NaN',strategy='median',axis=0)
imputer=imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        [nan, 25.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 24.0, 16.5],
#        [nan, 27.0, 16.5],
#        [nan, 22.0, 16.5],
#        [nan, 33.0, 13.0],
# ...

# %%
from sklearn.impute import SimpleImputer
simple=SimpleImputer(strategy='most_frequent')
x[:,0:1]=simple.fit_transform(x[:,0:1])

# %%
x
# Out:
# array([['Sales and Marketing', 28.0, 3.0],
#        ['Sales and Marketing', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Customer Relations', 22.0, 1.0],
#        ['Accounting', 27.0, 0.0],
#        ['Accounting', 26.0, 5.0],
#        ['Customer Relations', 24.0, 6.0],
#        ['Customer Relations', 29.0, 2.0],
#        ['Sales and Marketing', 29.0, 5.0],
#        ['Customer Relations', 30.0, 6.0],
#        ['Accounting', 26.0, 5.0],
#        ['Sales and Marketing', 26.0, 6.0],
#        ['Accounting', 24.0, 5.0],
#        ['Accounting', 22.0, 2.0],
#        ['Sales and Marketing', 25.0, 3.0],
#        ['Accounting', 25.0, 16.5],
#        ['Customer Relations', 22.0, 16.5],
#        ['Accounting', 25.0, 16.5],
#        ['Accounting', 27.0, 16.5],
#        ['Sales and Marketing', 25.0, 16.5],
#        ['Sales and Marketing', 22.0, 16.5],
#        ['Sales and Marketing', 22.0, 16.5],
#        ['Sales and Marketing', 24.0, 16.5],
# ...

# %%
data1=data

# %%
data1
# Out:
#     Employee Id First Name   Last Name           Department   Age  Experience  \
# 0             1        Joy        Bass  Sales and Marketing  28.0         3.0
# 1             2     Sheila       Garza  Sales and Marketing  22.0         1.0
# 2             3       John      Bryant   Customer Relations  22.0         1.0
# 3             4  Christian      Farley   Customer Relations  22.0         1.0
# 4             5   Colorado       Bowen           Accounting  27.0         0.0
# 5             6     Elijah    Matthews           Accounting  26.0         5.0
# 6             7         Bo      Mcleod   Customer Relations  24.0         6.0
# 7             8       Zena    Melendez   Customer Relations  29.0         2.0
# 8             9     Tucker     Michael  Sales and Marketing  29.0         5.0
# 9            10      Lucas        Rowe   Customer Relations  30.0         6.0
# 10           11    Mallory      Walker           Accounting  26.0         5.0
# ...

# %%
data1.groupby('Department').size()
# Out:
# Department
# Accounting             27
# Customer Relations     24
# Sales and Marketing    30
# dtype: int64

# %%
data1['Department']=data1['Department'].fillna('sales and marketing')

# %%
data1['Age']=data1['Age'].fillna(data1['Age']).mean()

# %%
data1['Experience']=data1['Experience'].fillna(data1['Experience']).median()

# %%
data1
# Out:
#     Employee Id First Name   Last Name           Department       Age  \
# 0             1        Joy        Bass  Sales and Marketing  37.97561
# 1             2     Sheila       Garza  Sales and Marketing  37.97561
# 2             3       John      Bryant   Customer Relations  37.97561
# 3             4  Christian      Farley   Customer Relations  37.97561
# 4             5   Colorado       Bowen           Accounting  37.97561
# 5             6     Elijah    Matthews           Accounting  37.97561
# 6             7         Bo      Mcleod   Customer Relations  37.97561
# 7             8       Zena    Melendez   Customer Relations  37.97561
# 8             9     Tucker     Michael  Sales and Marketing  37.97561
# 9            10      Lucas        Rowe   Customer Relations  37.97561
# 10           11    Mallory      Walker           Accounting  37.97561
# 11           12      Wanda      Wagner  Sales and Marketing  37.97561
# ...

# %%
data1.isnull().sum()
# Out:
# Employee Id    0
# First Name     0
# Last Name      0
# Department     0
# Age            0
# Experience     0
# Salary         0
# dtype: int64

# %% [markdown]
# # outlier

# %%
outlier=pd.read_excel('OutlierData.xlsx')

# %%
outlier
# Out:
#   Department  Age  Experience
# 0         HR   21           1
# 1         HR   33          12
# 2         IT   35          12
# 3         IT   36          12
# 4         HR   34          11
# 5         IT   33          13
# 6  Marketing   34          12
# 7         HR   32          10
# 8  Marketing   31           2
# 9         IT   55          35

# %%
q1=outlier.quantile(0.25)

# %%
q3=outlier.quantile(0.75)

# %%
IQR=q3-q1

# %%
IQR
# Out:
# Age           2.50
# Experience    1.75
# dtype: float64

# %%
q1
# Out:
# Age           32.25
# Experience    10.25
# Name: 0.25, dtype: float64

# %%
q3
# Out:
# Age           34.75
# Experience    12.00
# Name: 0.75, dtype: float64

# %%
outlier['Department']=outlier['Department'].astype('category')
outlier['Department']=outlier['Department'].cat.codes

# %%
outlier
# Out:
#    Department  Age  Experience
# 0           0   21           1
# 1           0   33          12
# 2           1   35          12
# 3           1   36          12
# 4           0   34          11
# 5           1   33          13
# 6           2   34          12
# 7           0   32          10
# 8           2   31           2
# 9           1   55          35

# %%
outlier[~((outlier<(q1-1.5*IQR))|(outlier>(q3+1.5*IQR))).any(axis=1)]
# Out:
#    Department  Age  Experience
# 1           0   33          12
# 2           1   35          12
# 3           1   36          12
# 4           0   34          11
# 5           1   33          13
# 6           2   34          12
# 7           0   32          10

# %%
outlier[((outlier<(q1-1.5*IQR))|(outlier>(q3+1.5*IQR))).any(axis=1)]
# Out:
#    Department  Age  Experience
# 0           0   21           1
# 8           2   31           2
# 9           1   55          35

# %%
data=pd.read_csv('data (1).csv')

# %%
data
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   45   61000        No
# 4  Germany   40   45000       Yes
# 5   France   35   58000       Yes
# 6    Spain   39   52000        No
# 7   France   48   79000       Yes
# 8  Germany   50   83000        No
# 9   France   37   67000       Yes

# %%
x=data.iloc[:,0:3].values

# %%
x
# Out:
# array([['France', 44, 72000],
#        ['Spain', 27, 48000],
#        ['Germany', 30, 54000],
#        ['Spain', 45, 61000],
#        ['Germany', 40, 45000],
#        ['France', 35, 58000],
#        ['Spain', 39, 52000],
#        ['France', 48, 79000],
#        ['Germany', 50, 83000],
#        ['France', 37, 67000]], dtype=object)

# %%
y=data.iloc[:,-1].values

# %%
y
# Out:
# array(['No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
label=LabelEncoder()
x[:,0]=label.fit_transform(x[:,0])

# %%
one=OneHotEncoder(categorical_features=[0])
x=one.fit_transform(x).toarray()
# Out:
# D:\an\lib\site-packages\sklearn\preprocessing\_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
pd.DataFrame(x)
# Out:
#      0    1    2     3        4
# 0  1.0  0.0  0.0  44.0  72000.0
# 1  0.0  0.0  1.0  27.0  48000.0
# 2  0.0  1.0  0.0  30.0  54000.0
# 3  0.0  0.0  1.0  45.0  61000.0
# 4  0.0  1.0  0.0  40.0  45000.0
# 5  1.0  0.0  0.0  35.0  58000.0
# 6  0.0  0.0  1.0  39.0  52000.0
# 7  1.0  0.0  0.0  48.0  79000.0
# 8  0.0  1.0  0.0  50.0  83000.0
# 9  1.0  0.0  0.0  37.0  67000.0

# %%
from sklearn.preprocessing import StandardScaler
stand=StandardScaler()
s_1=stand.fit_transform(x)

# %%
pd.DataFrame(s_1)
# Out:
#           0         1         2         3         4
# 0  1.224745 -0.654654 -0.654654  0.632299  0.818976
# 1 -0.816497 -0.654654  1.527525 -1.756387 -1.127105
# 2 -0.816497  1.527525 -0.654654 -1.334854 -0.640585
# 3 -0.816497 -0.654654  1.527525  0.772810 -0.072978
# 4 -0.816497  1.527525 -0.654654  0.070255 -1.370365
# 5  1.224745 -0.654654 -0.654654 -0.632299 -0.316238
# 6 -0.816497 -0.654654  1.527525 -0.070255 -0.802758
# 7  1.224745 -0.654654 -0.654654  1.194343  1.386583
# 8 -0.816497  1.527525 -0.654654  1.475365  1.710930
# 9  1.224745 -0.654654 -0.654654 -0.351277  0.413542

# %%
from sklearn.preprocessing import Normalizer
normalizer=Normalizer()
n_1=normalizer.fit_transform(x)

# %%
pd.DataFrame(n_1)
# Out:
#           0         1         2         3    4
# 0  0.000014  0.000000  0.000000  0.000611  1.0
# 1  0.000000  0.000000  0.000021  0.000562  1.0
# 2  0.000000  0.000019  0.000000  0.000556  1.0
# 3  0.000000  0.000000  0.000016  0.000738  1.0
# 4  0.000000  0.000022  0.000000  0.000889  1.0
# 5  0.000017  0.000000  0.000000  0.000603  1.0
# 6  0.000000  0.000000  0.000019  0.000750  1.0
# 7  0.000013  0.000000  0.000000  0.000608  1.0
# 8  0.000000  0.000012  0.000000  0.000602  1.0
# 9  0.000015  0.000000  0.000000  0.000552  1.0
